# %% [markdown]
# 对airmiles数据进行自相关分析

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import pandas as pd

pdata=pd.read_csv("http://image.cador.cn/data/airmiles.csv")
plot_acf(pdata.miles, lags=10, title="airmiles autocorrelation")
